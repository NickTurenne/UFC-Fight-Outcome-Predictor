# %% [markdown]
# # Exploratory Data Analysis
#
# This notebook is going to explore the raw and processed data to identify anomalies, spot patterns, and check assupmtions.
# ***

# %%
import sys
import pandas as pd
import numpy as np
from pathlib import Path

# %% [markdown]
# ### Raw Data
#
# This is the raw, uncleaned data gathered from this source on Kaggle:
#
# https://www.kaggle.com/datasets/neelagiriaditya/ufc-datasets-1994-2025
#
# Here our goal is to get a feel for the data.

# %%
project_root = Path().resolve().parents[0]
sys.path.append(str(project_root))

df_fighter = pd.read_csv(Path(project_root) / "data" / "raw" / "fighter_details.csv")
df_fight = pd.read_csv(Path(project_root) / "data" / "raw" / "fight_details.csv")
df_event = pd.read_csv(Path(project_root) / "data" / "raw" / "event_details.csv")

# %%
df_fighter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2611 entries, 0 to 2610
# Data columns (total 19 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          2611 non-null   object
#  1   name        2611 non-null   object
#  2   nick_name   1692 non-null   object
#  3   wins        2611 non-null   int64
#  4   losses      2611 non-null   int64
#  5   draws       2611 non-null   int64
#  6   height      2590 non-null   float64
#  7   weight      2593 non-null   float64
#  8   reach       1956 non-null   float64
#  9   stance      2534 non-null   object
#  10  dob         2455 non-null   object
#  11  splm        2611 non-null   float64
#  12  str_acc     2611 non-null   int64
#  13  sapm        2611 non-null   float64
#  14  str_def     2611 non-null   int64
#  15  td_avg      2611 non-null   float64
#  16  td_avg_acc  2611 non-null   int64
#  17  td_def      2611 non-null   int64
#  18  sub_avg     2611 non-null   float64
# dtypes: float64(7), int64(7), object(5)
# memory usage: 387.7+ KB

# %% [markdown]
# Here, we should be sure to note that of the 2611 listed fighters we can see the following:
# - 21 have no listed height
# - 655 have no listed reach
# - 77 have no listed stance
# - 156 have no listed date of birth
#
# All of these pieces of information are important for the model, so we must identify how to handle them properly (e.g. fill with generics, averages, drop, etc.).

# %%
df_fight.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8337 entries, 0 to 8336
# Data columns (total 86 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   event_name           8337 non-null   object
#  1   event_id             8337 non-null   object
#  2   fight_id             8337 non-null   object
#  3   r_name               8337 non-null   object
#  4   r_id                 8337 non-null   object
#  5   b_name               8337 non-null   object
#  6   b_id                 8337 non-null   object
#  7   division             8337 non-null   object
#  8   title_fight          8337 non-null   int64
#  9   method               8337 non-null   object
#  10  finish_round         8337 non-null   int64
#  11  match_time_sec       8337 non-null   int64
#  12  total_rounds         8306 non-null   float64
#  13  referee              8311 non-null   object
#  14  r_kd                 8316 non-null   float64
#  15  r_sig_str_landed     8316 non-null   float64
#  16  r_sig_str_atmpted    8316 non-null   float64
#  17  r_sig_str_acc        8278 non-null   float64
#  18  r_total_str_landed   8316 non-null   float64
#  19  r_total_str_atmpted  8316 non-null   float64
#  20  r_total_str_acc      8289 non-null   float64
#  21  r_td_landed          8316 non-null   float64
#  22  r_td_atmpted         8316 non-null   float64
#  23  r_td_acc             5651 non-null   float64
#  24  r_sub_att            8316 non-null   float64
#  25  r_ctrl               8135 non-null   float64
#  26  r_head_landed        8316 non-null   float64
#  27  r_head_atmpted       8316 non-null   float64
#  28  r_head_acc           8238 non-null   float64
#  29  r_body_landed        8316 non-null   float64
#  30  r_body_atmpted       8316 non-null   float64
#  31  r_body_acc           7479 non-null   float64
#  32  r_leg_landed         8316 non-null   float64
#  33  r_leg_atmpted        8316 non-null   float64
#  34  r_leg_acc            6753 non-null   float64
#  35  r_dist_landed        8316 non-null   float64
#  36  r_dist_atmpted       8316 non-null   float64
#  37  r_dist_acc           8198 non-null   float64
#  38  r_clinch_landed      8316 non-null   float64
#  39  r_clinch_atmpted     8316 non-null   float64
#  40  r_clinch_acc         6334 non-null   float64
#  41  r_ground_landed      8316 non-null   float64
#  42  r_ground_atmpted     8316 non-null   float64
#  43  r_ground_acc         5381 non-null   float64
#  44  r_landed_head_per    8316 non-null   float64
#  45  r_landed_body_per    8316 non-null   float64
#  46  r_landed_leg_per     8316 non-null   float64
#  47  r_landed_dist_per    8316 non-null   float64
#  48  r_landed_clinch_per  8316 non-null   float64
#  49  r_landed_ground_per  8316 non-null   float64
#  50  b_kd                 8316 non-null   float64
#  51  b_sig_str_landed     8316 non-null   float64
#  52  b_sig_str_atmpted    8316 non-null   float64
#  53  b_sig_str_acc        8258 non-null   float64
#  54  b_total_str_landed   8316 non-null   float64
#  55  b_total_str_atmpted  8316 non-null   float64
#  56  b_total_str_acc      8280 non-null   float64
#  57  b_td_landed          8316 non-null   float64
#  58  b_td_atmpted         8316 non-null   float64
#  59  b_td_acc             5211 non-null   float64
#  60  b_sub_att            8316 non-null   float64
#  61  b_ctrl               8135 non-null   float64
#  62  b_head_landed        8316 non-null   float64
#  63  b_head_atmpted       8316 non-null   float64
#  64  b_head_acc           8180 non-null   float64
#  65  b_body_landed        8316 non-null   float64
#  66  b_body_atmpted       8316 non-null   float64
#  67  b_body_acc           7340 non-null   float64
#  68  b_leg_landed         8316 non-null   float64
#  69  b_leg_atmpted        8316 non-null   float64
#  70  b_leg_acc            6769 non-null   float64
#  71  b_dist_landed        8316 non-null   float64
#  72  b_dist_atmpted       8316 non-null   float64
#  73  b_dist_acc           8208 non-null   float64
#  74  b_clinch_landed      8316 non-null   float64
#  75  b_clinch_atmpted     8316 non-null   float64
#  76  b_clinch_acc         6295 non-null   float64
#  77  b_ground_landed      8316 non-null   float64
#  78  b_ground_atmpted     8316 non-null   float64
#  79  b_ground_acc         4521 non-null   float64
#  80  b_landed_head_per    8316 non-null   float64
#  81  b_landed_body_per    8316 non-null   float64
#  82  b_landed_leg_per     8316 non-null   float64
#  83  b_landed_dist_per    8316 non-null   float64
#  84  b_landed_clinch_per  8316 non-null   float64
#  85  b_landed_ground_per  8316 non-null   float64
# dtypes: float64(73), int64(3), object(10)
# memory usage: 5.5+ MB

# %% [markdown]
# Here, we can see that of the 8337 fights there is also some fights with missing information, some important ones being:
# - Knockdowns
# - Total strikes
# - Signifcant strikes
#
# Since it appears only around 21 fights are missing this information, they could simply be removed (or they might get removed automatically if they happened pre 2000-11-17)

# %%
df_event.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8337 entries, 0 to 8336
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   event_id   8337 non-null   object
#  1   fight_id   8337 non-null   object
#  2   date       8337 non-null   object
#  3   location   8337 non-null   object
#  4   winner     8190 non-null   object
#  5   winner_id  8190 non-null   object
# dtypes: object(6)
# memory usage: 390.9+ KB

# %% [markdown]
# Here we can make a simple note that 147 fights ended with no winner, as such those fights can be removed.

# %%
# Format DateTime
df_event["date"] = pd.to_datetime(df_event["date"], format="%B %d, %Y")
df_fighter["dob"] = pd.to_datetime(df_fighter["dob"], format="%b %d, %Y")
# Drop fights with no winner
df_event = df_event.dropna(subset=["winner", "winner_id"])
# Drop fights before Unified Rules of MMA (UFC 28, November 17, 2000)
cutoff_date = pd.Timestamp("2000-11-17")
df_event = df_event[df_event["date"] >= cutoff_date]
# Sort the fights from oldest to newest for dataset construction
df_event = df_event.sort_values(by="date")

# Join events with fights
df_event_fights = pd.merge(df_event, df_fight, on="fight_id")
df_event_fights.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7943 entries, 0 to 7942
# Data columns (total 91 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   event_id_x           7943 non-null   object
#  1   fight_id             7943 non-null   object
#  2   date                 7943 non-null   datetime64[ns]
#  3   location             7943 non-null   object
#  4   winner               7943 non-null   object
#  5   winner_id            7943 non-null   object
#  6   event_name           7943 non-null   object
#  7   event_id_y           7943 non-null   object
#  8   r_name               7943 non-null   object
#  9   r_id                 7943 non-null   object
#  10  b_name               7943 non-null   object
#  11  b_id                 7943 non-null   object
#  12  division             7943 non-null   object
#  13  title_fight          7943 non-null   int64
#  14  method               7943 non-null   object
#  15  finish_round         7943 non-null   int64
#  16  match_time_sec       7943 non-null   int64
#  17  total_rounds         7943 non-null   float64
#  18  referee              7918 non-null   object
#  19  r_kd                 7943 non-null   float64
#  20  r_sig_str_landed     7943 non-null   float64
#  21  r_sig_str_atmpted    7943 non-null   float64
#  22  r_sig_str_acc        7918 non-null   float64
#  23  r_total_str_landed   7943 non-null   float64
#  24  r_total_str_atmpted  7943 non-null   float64
#  25  r_total_str_acc      7926 non-null   float64
#  26  r_td_landed          7943 non-null   float64
#  27  r_td_atmpted         7943 non-null   float64
#  28  r_td_acc             5403 non-null   float64
#  29  r_sub_att            7943 non-null   float64
#  30  r_ctrl               7943 non-null   float64
#  31  r_head_landed        7943 non-null   float64
#  32  r_head_atmpted       7943 non-null   float64
#  33  r_head_acc           7884 non-null   float64
#  34  r_body_landed        7943 non-null   float64
#  35  r_body_atmpted       7943 non-null   float64
#  36  r_body_acc           7219 non-null   float64
#  37  r_leg_landed         7943 non-null   float64
#  38  r_leg_atmpted        7943 non-null   float64
#  39  r_leg_acc            6532 non-null   float64
#  40  r_dist_landed        7943 non-null   float64
#  41  r_dist_atmpted       7943 non-null   float64
#  42  r_dist_acc           7877 non-null   float64
#  43  r_clinch_landed      7943 non-null   float64
#  44  r_clinch_atmpted     7943 non-null   float64
#  45  r_clinch_acc         6084 non-null   float64
#  46  r_ground_landed      7943 non-null   float64
#  47  r_ground_atmpted     7943 non-null   float64
#  48  r_ground_acc         5117 non-null   float64
#  49  r_landed_head_per    7943 non-null   float64
#  50  r_landed_body_per    7943 non-null   float64
#  51  r_landed_leg_per     7943 non-null   float64
#  52  r_landed_dist_per    7943 non-null   float64
#  53  r_landed_clinch_per  7943 non-null   float64
#  54  r_landed_ground_per  7943 non-null   float64
#  55  b_kd                 7943 non-null   float64
#  56  b_sig_str_landed     7943 non-null   float64
#  57  b_sig_str_atmpted    7943 non-null   float64
#  58  b_sig_str_acc        7912 non-null   float64
#  59  b_total_str_landed   7943 non-null   float64
#  60  b_total_str_atmpted  7943 non-null   float64
#  61  b_total_str_acc      7925 non-null   float64
#  62  b_td_landed          7943 non-null   float64
#  63  b_td_atmpted         7943 non-null   float64
#  64  b_td_acc             5010 non-null   float64
#  65  b_sub_att            7943 non-null   float64
#  66  b_ctrl               7943 non-null   float64
#  67  b_head_landed        7943 non-null   float64
#  68  b_head_atmpted       7943 non-null   float64
#  69  b_head_acc           7853 non-null   float64
#  70  b_body_landed        7943 non-null   float64
#  71  b_body_atmpted       7943 non-null   float64
#  72  b_body_acc           7103 non-null   float64
#  73  b_leg_landed         7943 non-null   float64
#  74  b_leg_atmpted        7943 non-null   float64
#  75  b_leg_acc            6547 non-null   float64
#  76  b_dist_landed        7943 non-null   float64
#  77  b_dist_atmpted       7943 non-null   float64
#  78  b_dist_acc           7877 non-null   float64
#  79  b_clinch_landed      7943 non-null   float64
#  80  b_clinch_atmpted     7943 non-null   float64
#  81  b_clinch_acc         6057 non-null   float64
#  82  b_ground_landed      7943 non-null   float64
#  83  b_ground_atmpted     7943 non-null   float64
#  84  b_ground_acc         4351 non-null   float64
#  85  b_landed_head_per    7943 non-null   float64
#  86  b_landed_body_per    7943 non-null   float64
#  87  b_landed_leg_per     7943 non-null   float64
#  88  b_landed_dist_per    7943 non-null   float64
#  89  b_landed_clinch_per  7943 non-null   float64
#  90  b_landed_ground_per  7943 non-null   float64
# dtypes: datetime64[ns](1), float64(73), int64(3), object(14)
# memory usage: 5.5+ MB

# %% [markdown]
# After some basic filtering, we can see the data has slimmed down to 7943 fights. This dropping of the fights with no winners and the old fights seems to have fixed the issues with missing values. Some accuracy statistics are still missing, but this is most likely cause by have no value if the fighter did not attempt any actions (as division by 0 is an impossibility).
# ***

# %% [markdown]
# ### Processed Data
#
# Here we examine at the data set that we have created after it has been cleaned and processed.
